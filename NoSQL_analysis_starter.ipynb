# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6476a30b01cf505b81aa37f6'),
#  'geocode': {'latitude': Decimal128('51.083812'),
#              'longitude': Decimal128('1.195625')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']
establishments
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'uk_food'), 'establishments')

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
hygiene_query = {'scores.Hygiene': 20}

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(hygiene_query)
print(f"establishments had {count} Hygiene with score 20\n"
     f"\n")

# Display the first document in the results using pprint
pprint(establishments.find_one(hygiene_query))
# Out:
# establishments had 41 Hygiene with score 20
#
#
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6476a30b01cf505b81aa5329'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
hygiene_query_df = pd.DataFrame(establishments.find(hygiene_query))

# Display the number of rows in the DataFrame
print("Rows in hygiene_query DataFrame: ", len(hygiene_query_df))

# Display the first 10 rows of the DataFrame
hygiene_query_df.head(10)
# Out:
# Rows in hygiene_query DataFrame:  41
#                         _id   FHRSID  ChangesByServerID  \
# 0  6476a30b01cf505b81aa5329   110681                  0
# 1  6476a30b01cf505b81aa56ac   612039                  0
# 2  6476a30c01cf505b81aa59b5   730933                  0
# 3  6476a30c01cf505b81aa5ba7   172735                  0
# 4  6476a30c01cf505b81aa5bb2   172953                  0
# 5  6476a30c01cf505b81aa6550   512854                  0
# 6  6476a30c01cf505b81aa6778  1537089                  0
# 7  6476a30c01cf505b81aa7c9e   155648                  0
# 8  6476a30c01cf505b81aa80e0  1012883                  0
# 9  6476a30d01cf505b81aa88f3   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...        FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
#
#                                              geocode RightToReply  \
# 0      {'longitude': 0.27694, 'latitude': 50.769705}
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3      {'longitude': 0.10202, 'latitude': 50.770885}
# 4     {'longitude': 0.101446, 'latitude': 50.770724}
# 5     {'longitude': 0.736349, 'latitude': 51.541448}
# 6   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7     {'longitude': 0.602364, 'latitude': 51.591515}
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9      {'longitude': 0.462307, 'latitude': 51.57005}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
london_query = {
                'LocalAuthorityName': {'$regex': 'London'}
                ,
                'RatingValue': {'$gte': 4}
               }

# Use count_documents to display the number of documents in the result
london_query_count = establishments.count_documents(london_query)
print(f"establishments had {london_query_count} London Local Authority Rating Value greater than or equal to 4 \n"
      f"\n")

# Display the first document in the results using pprint
pprint(establishments.find_one(london_query))
# Out:
# establishments had 33 London Local Authority Rating Value greater than or equal to 4
#
#
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6476a30c01cf505b81aa6d4a'),
#  'geocode': {'latitude': Decimal128('51.369321'),
#              'longitude': Decimal128('0.508551')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
london_query_df = pd.DataFrame(establishments.find(london_query))

# Display the number of rows in the DataFrame
print("Rows in london_query DataFrame: ", len(london_query_df))

# Display the first 10 rows of the DataFrame
london_query_df.head(10)
# Out:
# Rows in london_query DataFrame:  33
#                         _id   FHRSID  ChangesByServerID  \
# 0  6476a30c01cf505b81aa6d4a   621707                  0
# 1  6476a30c01cf505b81aa706b  1130836                  0
# 2  6476a30c01cf505b81aa7bb8   293783                  0
# 3  6476a30d01cf505b81aa89b0  1315095                  0
# 4  6476a30d01cf505b81aa89b1   294474                  0
# 5  6476a30d01cf505b81aa90c1   294900                  0
# 6  6476a30e01cf505b81aab1d0   293756                  0
# 7  6476a30e01cf505b81aab596   878523                  0
# 8  6476a30e01cf505b81aab5b1   295107                  0
# 9  6476a30e01cf505b81aab5b3   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# 4             PI/000014647              Tilbury Seafarers Centre
# 5             PI/000019066                            Mv Valulla
# 6             PI/000002538                         Tereza Joanne
# 7             PI/000029844                      Brick Lane Brews
# 8             PI/000020749                      City Bar & Grill
# 9             PI/000016185                              WH Smith
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# 4  Restaurant/Cafe/Canteen               1
# 5  Other catering premises            7841
# 6  Other catering premises            7841
# 7  Restaurant/Cafe/Canteen               1
# 8  Restaurant/Cafe/Canteen               1
# 9        Retailers - other            4613
#
#                                         AddressLine1  \
# 0         Oak Apple Farm Building 103 Sheernes Docks
# 1                                 Cherry Garden Pier
# 2                                         Ferry Road
# 3                                  Leslie Ford House
# 4                          Tenants Row Tilbury Docks
# 5  Reeds River Cruises LtdKings ReachRiver Thames...
# 6  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                       Air side London City Airport
# 8                      London City Airport (Airside)
# 9                                London City Airport
#
#                        AddressLine2 AddressLine3  ...  \
# 0                       Sheppy Kent               ...
# 1  Cherry Garden Street Rotherhithe     Charlton  ...
# 2              South Benfleet Essex               ...
# 3                           Tilbury     Charlton  ...
# 4                     Tilbury Essex               ...
# 5                            London               ...
# 6                            London               ...
# 7                            London               ...
# 8                            London               ...
# 9                 Silvertown London               ...
#
#                                LocalAuthorityWebSite  \
# 0  http://www.cityoflondon.gov.uk/Corporation/hom...
# 1  http://www.cityoflondon.gov.uk/Corporation/hom...
# 2  http://www.cityoflondon.gov.uk/Corporation/hom...
# 3  http://www.cityoflondon.gov.uk/Corporation/hom...
# 4  http://www.cityoflondon.gov.uk/Corporation/hom...
# 5  http://www.cityoflondon.gov.uk/Corporation/hom...
# 6  http://www.cityoflondon.gov.uk/Corporation/hom...
# 7  http://www.cityoflondon.gov.uk/Corporation/hom...
# 8  http://www.cityoflondon.gov.uk/Corporation/hom...
# 9  http://www.cityoflondon.gov.uk/Corporation/hom...
#
#              LocalAuthorityEmailAddress  \
# 0  publicprotection@cityoflondon.gov.uk
# 1  publicprotection@cityoflondon.gov.uk
# 2  publicprotection@cityoflondon.gov.uk
# 3  publicprotection@cityoflondon.gov.uk
# 4  publicprotection@cityoflondon.gov.uk
# 5  publicprotection@cityoflondon.gov.uk
# 6  publicprotection@cityoflondon.gov.uk
# 7  publicprotection@cityoflondon.gov.uk
# 8  publicprotection@cityoflondon.gov.uk
# 9  publicprotection@cityoflondon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...        FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 7  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...        FHRS
# 8  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.508551, 'latitude': 51.369321}
# 1  {'longitude': 0.249255999922752, 'latitude': 5...
# 2     {'longitude': 0.561954, 'latitude': 51.543831}
# 3  {'longitude': 0.346336990594864, 'latitude': 5...
# 4     {'longitude': 0.346325, 'latitude': 51.464078}
# 5     {'longitude': 0.287555, 'latitude': 51.504071}
# 6     {'longitude': 0.069286, 'latitude': 51.501121}
# 7     {'longitude': 0.048006, 'latitude': 51.503733}
# 8  {'longitude': 0.0479655750095844, 'latitude': ...
# 9  {'longitude': 0.0479655750095844, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4627.439468            False
# 1  4627.873179            False
# 2  4631.968418            False
# 3  4636.846754            False
# 4  4636.847650            False
# 5  4640.460834            False
# 6  4648.301822            False
# 7  4649.173485            False
# 8  4649.188850            False
# 9  4649.188850            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %%
london_query_df[{"BusinessName","RatingValue","LocalAuthorityName"}]
# Out:
#             LocalAuthorityName  RatingValue  \
# 0   City of London Corporation            4
# 1   City of London Corporation            5
# 2   City of London Corporation            4
# 3   City of London Corporation            5
# 4   City of London Corporation            5
# 5   City of London Corporation            5
# 6   City of London Corporation            5
# 7   City of London Corporation            4
# 8   City of London Corporation            5
# 9   City of London Corporation            5
# 10  City of London Corporation            5
# 11  City of London Corporation            5
# 12  City of London Corporation            5
# 13  City of London Corporation            5
# 14  City of London Corporation            5
# 15  City of London Corporation            4
# 16  City of London Corporation            5
# 17  City of London Corporation            5
# 18  City of London Corporation            5
# 19  City of London Corporation            5
# 20  City of London Corporation            5
# 21  City of London Corporation            5
# 22  City of London Corporation            5
# 23  City of London Corporation            5
# 24  City of London Corporation            5
# 25  City of London Corporation            5
# 26  City of London Corporation            5
# 27  City of London Corporation            5
# 28  City of London Corporation            5
# 29  City of London Corporation            5
# 30  City of London Corporation            5
# 31  City of London Corporation            5
# 32  City of London Corporation            5
#
#                             BusinessName
# 0                              Charlie's
# 1                Mv City Cruises Erasmus
# 2              Benfleet Motor Yacht Club
# 3   Coombs Catering t/a The Lock and Key
# 4               Tilbury Seafarers Centre
# 5                             Mv Valulla
# 6                          Tereza Joanne
# 7                       Brick Lane Brews
# 8                       City Bar & Grill
# 9                               WH Smith
# 10         The Nuance Group (UK) Limited
# 11                            Caffè Nero
# 12                            Jet Centre
# 13                Mv Sunborn Yacht Hotel
# 14                     Good Hotel London
# 15                         La Nonna lina
# 16             Wake Up Docklands Limited
# 17                      MV Venus Clipper
# 18                    MV Typhoon clipper
# 19                       MV Moon clipper
# 20                    MV Jupiter clipper
# 21                    MV Monsoon clipper
# 22                     MV Meteor clipper
# 23                    MV Tornado clipper
# 24                    MV Mercury clipper
# 25                    MV Cyclone clipper
# 26                    MV Neptune clipper
# 27                  MV Hurricane clipper
# 28                     MV Galaxy clipper
# 29                      Mv Storm Clipper
# 30                     MV Aurora clipper
# 31                        MV Sun clipper
# 32                       Canary Wharf 1V

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Find "Penang Flavours" Latitude & Longitude
pprint(establishments.find_one({'BusinessName':'Penang Flavours'},{'geocode.latitude','geocode.longitude'}))
# Out:
# {'_id': ObjectId('6476a310fa6fdb64924c77f1'),
#  'geocode': {'latitude': Decimal128('51.49014200'),
#              'longitude': Decimal128('0.08384000')}}

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.490142
longitude = 0.08384

nearest_query = {'geocode.latitude': {'$lte':(latitude +  degree_search)},
                 'geocode.latitude': {'$gte':(latitude -  degree_search)},
                 'geocode.longitude': {'$lte':(longitude +  degree_search)},
                 'geocode.longitude': {'$gte':(longitude -  degree_search)},
                 'RatingValue': 5
                }

# sort in ascending order by hygiene score
sort = [('establishments.scores.Hygiene', 1)] 

# limit the results to the first 5
for result in establishments.find(nearest_query).sort(sort).limit(5):
    pprint(nearest_query)
# Out:
# {'RatingValue': 5,
#  'geocode.latitude': {'$gte': 51.480142},
#  'geocode.longitude': {'$gte': 0.07384}}
# {'RatingValue': 5,
#  'geocode.latitude': {'$gte': 51.480142},
#  'geocode.longitude': {'$gte': 0.07384}}
# {'RatingValue': 5,
#  'geocode.latitude': {'$gte': 51.480142},
#  'geocode.longitude': {'$gte': 0.07384}}
# {'RatingValue': 5,
#  'geocode.latitude': {'$gte': 51.480142},
#  'geocode.longitude': {'$gte': 0.07384}}
# {'RatingValue': 5,
#  'geocode.latitude': {'$gte': 51.480142},
#  'geocode.longitude': {'$gte': 0.07384}}

# %%
# Convert result to Pandas DataFrame
nearest_query_df = pd.DataFrame(establishments.find(nearest_query).sort(sort).limit(5))
nearest_query_df
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  6476a30b01cf505b81aa5651   611631                  0
# 1  6476a30b01cf505b81aa5653   611980                  0
# 2  6476a30b01cf505b81aa5648   612189                  0
# 3  6476a30b01cf505b81aa5643   908226                  0
# 4  6476a30b01cf505b81aa5650  1148945                  0
#
#   LocalAuthorityBusinessID             BusinessName             BusinessType  \
# 0            10/00010/FOOD             Royal Albion        Pub/bar/nightclub
# 1                1762/FOOD            Walton Tavern        Pub/bar/nightclub
# 2                  3254/HS             Anchor Lodge          Caring Premises
# 3            16/00139/FOOD  The Last Fisherman Cafe  Restaurant/Cafe/Canteen
# 4            19/00096/FOOD        Foray Enterprises   Takeaway/sandwich shop
#
#    BusinessTypeID        AddressLine1        AddressLine2        AddressLine3  \
# 0            7843    The Royal Albion          The Parade  Walton On The Naze
# 1            7843  30 - 31 The Parade  Walton-on-the-Naze               Essex
# 2               5        Cliff Parade  Walton-on-the-Naze               Essex
# 3               1    Eastcliffe Kiosk        East Terrace  Walton On The Naze
# 4            7844            The Shop   Princes Esplanade  Walton On The Naze
#
#    ...          LocalAuthorityWebSite  LocalAuthorityEmailAddress  \
# 0  ...  http://www.tendringdc.gov.uk/  fhsadmin@tendringdc.gov.uk
# 1  ...  http://www.tendringdc.gov.uk/  fhsadmin@tendringdc.gov.uk
# 2  ...  http://www.tendringdc.gov.uk/  fhsadmin@tendringdc.gov.uk
# 3  ...  http://www.tendringdc.gov.uk/  fhsadmin@tendringdc.gov.uk
# 4  ...  http://www.tendringdc.gov.uk/  fhsadmin@tendringdc.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 1  {'Hygiene': 5, 'Structural': 0, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0      {'longitude': 1.273099, 'latitude': 51.84913}
# 1     {'longitude': 1.272087, 'latitude': 51.848187}
# 2       {'longitude': 1.2819, 'latitude': 51.856908}
# 3     {'longitude': 1.278971, 'latitude': 51.853985}
# 4  {'longitude': 1.27618598937988, 'latitude': 51...
#
#       Distance NewRatingPending  \
# 0  4617.847741            False
# 1  4617.848109            False
# 2  4617.828604            False
# 3  4617.822272            False
# 4  4617.847876            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

local_authority_query = {'$match': {'scores.Hygiene': 0}}

local_authority_groups_query = {'$group': {'_id': '$LocalAuthorityName', 'count': {'$sum': 1 }}}

local_authority_sort = {'$sort': { 'count': -1 }}

# pipeline (query, group, sort)
pipeline = [local_authority_query, local_authority_groups_query, local_authority_sort]

# %%
# Run the pipeline through the aggregate method and save the results to a variable
local_authority_results = list(establishments.aggregate(pipeline))

# %%
# Print the number of documents in the result
print(f"establishments had {len(local_authority_results)} documents in pipeline grouped local authority with hygine score 0 \n"
      f"\n")
# Out:
# establishments had 55 documents in pipeline grouped local authority with hygine score 0

# %%
# Print the first 10 results
pprint(local_authority_results[0:10])
# Out:
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
local_authority_result_df = pd.DataFrame(local_authority_results)

# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(local_authority_result_df))

# Display the first 10 rows of the DataFrame
local_authority_result_df.head(10)
# Out:
# Rows in DataFrame:  55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
